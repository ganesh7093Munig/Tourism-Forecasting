# %%
import numpy as np
import pandas as pd
df = pd.read_excel("Dataset1.xlsx", engine="openpyxl")

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('real_final.csv')

# %%
df3 = pd.read_csv('enhanced_data.csv')

# %%
df1 = df.loc[:, ~df.columns.str.contains("^Unnamed")]

# %%
df2=df1.copy()

# %%
df2[['holidays','Special Day Weighted','Piligrims_7Day_Avg','Festival intensity']] = df3[['Special Day','Special Day Weighted','Piligrims_7Day_Avg','Festival Intensity']]  # Add column 'B' from df1 to df2

# %%
df2
# Out:
#             Date  Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0     2022-01-01      36560     14084   2.15        43        23           16
# 1     2022-01-02      38894     12270   3.93        41        25           14
# 2     2022-01-03      31776     16046   2.69        40        19            0
# 3     2022-01-04      31523     14692   2.45        45        17           22
# 4     2022-01-05      32044     17558   2.61        32        14           21
# ...          ...        ...       ...    ...       ...       ...          ...
# 1091  2024-12-27      66715     24503   4.06        79        55            0
# 1092  2024-12-28      78414     26100   3.45        76        50            0
# 1093  2024-12-29      84950     21098   3.80        64        42            0
# 1094  2024-12-30      68298     16544   4.10        68        42            0
# 1095  2024-12-31      62495     19298   3.80        68        35            0
#
# ...

# %%
df2.drop(columns=['Date',"is_normal","is_Nagulapuram Sri Vedanarayanaswamivari Brahmotsavam","is_Devuni Kadapa Sri Lakshmi Venkateswaraswamivari Brahmotsavams"	,"days_until_next_festival"	,"days_since_last_festival"], inplace=True)

# %%
df2.to_csv("realtime.csv", index=False)

# %%
df2
# Out:
#       Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0         36560     14084   2.15        43        23           16
# 1         38894     12270   3.93        41        25           14
# 2         31776     16046   2.69        40        19            0
# 3         31523     14692   2.45        45        17           22
# 4         32044     17558   2.61        32        14           21
# ...         ...       ...    ...       ...       ...          ...
# 1091      66715     24503   4.06        79        55            0
# 1092      78414     26100   3.45        76        50            0
# 1093      84950     21098   3.80        64        42            0
# 1094      68298     16544   4.10        68        42            0
# 1095      62495     19298   3.80        68        35            0
#
#       tirumala darshan  srinivasam complex  tirumala darshan tickets  \
# 0                    9                   0                         0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df2[['Tonsures',	'Hundi'	,'Tirupati'	,'Tirumala'	,'VIP darshan'	,'tirumala darshan'	,'srinivasam complex'	,'tirumala darshan tickets'	,'tirupati balaji.ap.gov.in',	'condition'	,'temperature'	,'Timestamp'	,'weekday'	,'festival_count'	,'festival_impact',"Piligrims_7Day_Avg"]],df2['Piligrims'],test_size=0.20,random_state=3)

# %%
x_train.shape,x_test.shape
# Out:
# ((876, 16), (220, 16))

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector = VarianceThreshold(threshold=0)
X_selected = selector.fit_transform(x_train)

# %%
selector.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Compute Pearson correlation and plot heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(x_train.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Pearson Correlation Heatmap")
plt.show()

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns())):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
        return col_corr

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set to store correlated column names
    corr_matrix = dataset.corr()  # Compute correlation matrix
    
    for i in range(len(corr_matrix.columns)):  # Loop through columns
        for j in range(i):  # Only check lower triangle
            if abs(corr_matrix.iloc[i, j]) > threshold:  # Check correlation
                colname = corr_matrix.columns[i]  # Get column name
                col_corr.add(colname)  # Add to set
                
    return col_corr

# %%
corr_features=correlation(x_train,0.5)
len(set(corr_features))
# Out:
# 5

# %%
corr_features
# Out:
# {'Piligrims_7Day_Avg',
#  'Tirumala',
#  'festival_impact',
#  'tirumala darshan',
#  'tirumala darshan tickets'}

# %%
df2
# Out:
#       Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0         36560     14084   2.15        43        23           16
# 1         38894     12270   3.93        41        25           14
# 2         31776     16046   2.69        40        19            0
# 3         31523     14692   2.45        45        17           22
# 4         32044     17558   2.61        32        14           21
# ...         ...       ...    ...       ...       ...          ...
# 1091      66715     24503   4.06        79        55            0
# 1092      78414     26100   3.45        76        50            0
# 1093      84950     21098   3.80        64        42            0
# 1094      68298     16544   4.10        68        42            0
# 1095      62495     19298   3.80        68        35            0
#
#       tirumala darshan  srinivasam complex  tirumala darshan tickets  \
# 0                    9                   0                         0
# ...

# %%
df2
# Out:
#       Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0         36560   14084.0   2.15        43        23           16
# 1         38894   12270.0   3.93        41        25           14
# 2         31776   16046.0   2.69        40        19            0
# 3         31523   14692.0   2.45        45        17           22
# 4         32044   17558.0   2.61        32        14           21
# ...         ...       ...    ...       ...       ...          ...
# 1091      66715   24503.0   4.06        79        55            0
# 1092      78414   26100.0   3.45        76        50            0
# 1093      84950   21098.0   3.80        64        42            0
# 1094      68298   16544.0   4.10        68        42            0
# 1095      62495   19298.0   3.80        68        35            0
#
#       tirumala darshan  temperature     Timestamp  weekday  \
# 0                    9        71.60  1.640995e+09        1
# ...

# %%
import pandas as pd

# Apply Target Encoding: Replace each condition with the mean value of 'PILGRIMS'
condition_mean_mapping = df2.groupby('newcondition')['Piligrims'].mean().to_dict()
df2['CONDITIONS_ENCODED'] = df2['newcondition'].map(condition_mean_mapping)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Initialize Label Encoder
encoder = LabelEncoder()

# Apply Label Encoding to 'condition' column
df2['condition_encoded'] = encoder.fit_transform(df2['newcondition'])

# %%
df4 = pd.read_csv('unpreprocesseddata.csv', encoding='latin1')

# %%
df4
# Out:
#             Date  Piligrims  Tonsures  Hundi  \
# 0     01-01-2022      36560   14084.0   2.15
# 1     02-01-2022      38894   12270.0   3.93
# 2     03-01-2022      31776   16046.0   2.69
# 3     04-01-2022      31523   14692.0   2.45
# 4     05-01-2022      32044   17558.0   2.61
# ...          ...        ...       ...    ...
# 1091  27-12-2024      66715   24503.0   4.06
# 1092  28-12-2024      78414   26100.0   3.45
# 1093  29-12-2024      84950   21098.0   3.80
# 1094  30-12-2024      68298   16544.0   4.10
# 1095  31-12-2024      62495   19298.0   3.80
#
#                                             Special Day  Tirupati  Tirumala  \
# 0                                         New Years Day        43        23
# 1     Amavasya, Sravanam, Tirupati Sri G.T Adhyayano...        41        25
# 2         Maha Sivaratri, Tirupati Sri KT Nandi Vahanam        40        19
# 3                                              Amavasya        45        17
# ...

# %%
df2['srinivascomplex'] = df4['srinivasam complex']
df2['tiru.balaji'] = df4['tirupati balaji.ap.gov.in']

# %%
df2
# Out:
#       Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0         36560   14084.0   2.15        43        23           16
# 1         38894   12270.0   3.93        41        25           14
# 2         31776   16046.0   2.69        40        19            0
# 3         31523   14692.0   2.45        45        17           22
# 4         32044   17558.0   2.61        32        14           21
# ...         ...       ...    ...       ...       ...          ...
# 1091      66715   24503.0   4.06        79        55            0
# 1092      78414   26100.0   3.45        76        50            0
# 1093      84950   21098.0   3.80        64        42            0
# 1094      68298   16544.0   4.10        68        42            0
# 1095      62495   19298.0   3.80        68        35            0
#
#       tirumala darshan  temperature     Timestamp  weekday  condition_encoded  \
# 0                    9        71.60  1.640995e+09        1                  3
# ...

# %%
df2
# Out:
#       Piligrims  Tonsures  Hundi  Tirupati  Tirumala  VIP darshan  \
# 0         36560   14084.0   2.15        43        23           16
# 1         38894   12270.0   3.93        41        25           14
# 2         31776   16046.0   2.69        40        19            0
# 3         31523   14692.0   2.45        45        17           22
# 4         32044   17558.0   2.61        32        14           21
# ...         ...       ...    ...       ...       ...          ...
# 1091      66715   24503.0   4.06        79        55            0
# 1092      78414   26100.0   3.45        76        50            0
# 1093      84950   21098.0   3.80        64        42            0
# 1094      68298   16544.0   4.10        68        42            0
# 1095      62495   19298.0   3.80        68        35            0
#
#       tirumala darshan  temperature     Timestamp  weekday  \
# 0                    9        71.60  1.640995e+09        1
# ...

# %%
df2 = df2.drop(columns=['CONDITIONS_ENCODED', 'newcondition'])

# %%
import pandas as pd

def correlation_with_target(dataset, x_features, y_feature, threshold):
    """
    Finds features in x_features that have a correlation greater than the given threshold with y_feature.

    Parameters:
    dataset (pd.DataFrame): The input DataFrame.
    x_features (list): List of feature names to check correlation with y_feature.
    y_feature (str): The target variable to compare against.
    threshold (float): The correlation threshold.

    Returns:
    dict: Dictionary with feature pairs as keys (e.g., "PILGRIMS-TONSURES") and their correlation coefficient as values,
          where correlation > threshold with y_feature.
    """
    col_corr = {}  # Dictionary to store correlated feature pairs and their coefficients
    corr_matrix = dataset.corr()  # Compute correlation matrix
    
    if y_feature not in dataset.columns:
        raise ValueError(f"Target variable '{y_feature}' not found in dataset columns")
    
    for feature in x_features:
        if feature in dataset.columns:
            correlation_value = corr_matrix.loc[feature, y_feature]
            if abs(correlation_value) > threshold:
                col_corr[f"{y_feature}-{feature}"] = correlation_value

    return col_corr

# Example usage
#x = [	'Tirupati'	,'Tirumala','condition'	,'temperature'	,'Timestamp','weekday','festival_impact','holidays']
#y = 'Piligrims'

x=['Tonsures',	'Hundi'	,'Tirupati'	,'Tirumala'	,'VIP darshan'	,'tirumala darshan'	,'srinivasam complex'	,'tirumala darshan tickets'	,'tirupati balaji.ap.gov.in',	'condition'	,'temperature'	,'Timestamp'	,'weekday'	,'festival_count'	,'festival_impact','holidays','holidays','Special Day Weighted','Piligrims_7Day_Avg','Festival intensity']
y='Piligrims'
# Assuming 'df' is your dataset
correlated_features = correlation_with_target(df2, x, y, 0)
for pair, value in correlated_features.items():
    print(f"{pair}: {value}")
# Out:
# Piligrims-Tonsures: 0.6916994364030916
# Piligrims-Hundi: 0.36909236061340217
# Piligrims-Tirupati: 0.2905804808065508
# Piligrims-Tirumala: 0.20327550698880775
# Piligrims-VIP darshan: 0.08704692738862414
# Piligrims-tirumala darshan: 0.10920770865055628
# Piligrims-srinivasam complex: -0.06736997992408329
# Piligrims-tirumala darshan tickets: -0.013431824046358792
# Piligrims-tirupati balaji.ap.gov.in: -0.06017873791252766
# Piligrims-condition: 0.12877227064171864
# Piligrims-temperature: 0.24174239535769187
# Piligrims-Timestamp: 0.2322509601777595
# Piligrims-weekday: 0.39413544221193775
# Piligrims-festival_count: 0.060654868203733184
# Piligrims-festival_impact: 0.6319685342100817
# Piligrims-holidays: 0.06972097683017875
# Piligrims-Special Day Weighted: 0.06972097683016928
# Piligrims-Piligrims_7Day_Avg: 0.7620028122367101
# Piligrims-Festival intensity: 0.24238760711903826

# %%
from sklearn.linear_model import LinearRegression

# %%
print(df2.isnull().sum())
# Out:
# Piligrims           0
# Tonsures            0
# Hundi               0
# Tirupati            0
# Tirumala            0
# VIP darshan         0
# tirumala darshan    0
# condition           0
# temperature         0
# Timestamp           0
# weekday             0
# dtype: int64

# %%
df2['newcondition'] = df3['condition']

# %%
import pandas as pd

# Apply Target Encoding: Replace each condition with the mean value of 'PILGRIMS'
condition_mean_mapping = df_combined.groupby('conditions')['PILGRIMS'].mean().to_dict()
df_combined['CONDITIONS_ENCODED'] = df_combined['conditions'].map(condition_mean_mapping)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow import keras

# Load dataset (assuming df2 is preloaded)
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']

y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# Standardization for models that require scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define models
models = {
    #"Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=3),
    "Extra Trees": ExtraTreesRegressor(n_estimators=200, random_state=3),
    "XGBoost": XGBRegressor(n_estimators=100, random_state=3),
    "LightGBM": LGBMRegressor(n_estimators=100, random_state=3),
    "SVR": SVR(kernel='rbf', C=100, epsilon=0.1)
}

# Train and evaluate each model
results = {}
for name, model in models.items():
    if name == "SVR":
        model.fit(X_train_scaled, y_train)  # Use scaled data for SVR
        y_pred = model.predict(X_test_scaled)
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
    
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    results[name] = [mae, rmse, r2]

# Neural Network (Deep Learning Model)
def build_nn():
    model = keras.Sequential([
        keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        keras.layers.Dense(32, activation='relu'),
        keras.layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

nn_model = build_nn()
nn_model.fit(X_train_scaled, y_train, epochs=50, batch_size=16, verbose=0, validation_split=0.2)
y_pred_nn = nn_model.predict(X_test_scaled).flatten()

mae_nn = mean_absolute_error(y_test, y_pred_nn)
mse_nn = mean_squared_error(y_test, y_pred_nn)
rmse_nn = np.sqrt(mse_nn)
r2_nn = r2_score(y_test, y_pred_nn)
results["Neural Network"] = [mae_nn, rmse_nn, r2_nn]

# Convert results to DataFrame and print
results_df = pd.DataFrame(results, index=["MAE", "RMSE", "R2"]).T
print(results_df.sort_values(by="R2", ascending=False))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000597 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 998
# [LightGBM] [Info] Number of data points in the train set: 876, number of used features: 8
# [LightGBM] [Info] Start training from score 68124.123288
# C:\Users\girishmunigeti\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#                            MAE          RMSE        R2
# Extra Trees        3731.022818   4924.405080  0.817180
# ...

# %%
#This is the updated version of the randomforestregressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming df2 is already loaded
# Define features and target
features =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
target = 'Piligrims'

# Train-test split
X = df2[features]
y = df2[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3)

# Feature Scaling (Apply only to numeric features if necessary)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf = RandomForestRegressor(random_state=3)
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)

# Best model from Grid Search
best_rf = grid_search.best_estimator_

# Cross-Validation Score (5-Fold CV)
cv = KFold(n_splits=5, shuffle=True, random_state=3)
cv_scores = cross_val_score(best_rf, X_train_scaled, y_train, cv=cv, scoring='r2')
print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean CV R² Score: {np.mean(cv_scores):.4f}")

# Predictions
y_pred = best_rf.predict(X_test_scaled)

# Evaluation Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print evaluation results
print("\nModel Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.4f}")

# Feature Importance Plot
importances = best_rf.feature_importances_
plt.figure(figsize=(8, 5))
plt.barh(features, importances, color='teal')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance in Random Forest")
plt.show()
# Out:
# Cross-Validation R² Scores: [0.75424762 0.79169774 0.75548238 0.76631932 0.79903805]
# Mean CV R² Score: 0.7734
#
# Model Evaluation Metrics:
# Mean Absolute Error (MAE): 3910.78
# Mean Squared Error (MSE): 25701106.81
# Root Mean Squared Error (RMSE): 5069.63
# R² Score: 0.8062

# %%
from sklearn.model_selection import cross_val_score, KFold

# Define the number of folds
k = 5  # You can change this (e.g., 10 for better results)

# Initialize K-Fold Cross-Validation
kf = KFold(n_splits=k, shuffle=True, random_state=3)

# Initialize the model
rf_model = RandomForestRegressor(n_estimators=100, random_state=3)
x = ['Tonsures','Hundi','Tirupati','temperature','Timestamp','weekday','festival_impact']
y = 'Piligrims'

# Perform Cross-Validation
cv_scores = cross_val_score(rf_model, df2[x], df2[y], cv=kf, scoring='r2')

# Print the cross-validation results
print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation R² Scores: [0.80485527 0.75839441 0.84224843 0.67926962 0.77049049]
# Mean R² Score: 0.7711
# Standard Deviation: 0.0544

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestRegressor(random_state=3), param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(df2[x], df2[y])

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}

# %%
# Train the model with the best parameters
optimized_rf = RandomForestRegressor(
    max_depth=10,
    min_samples_leaf=1,
    min_samples_split=5,
    n_estimators=100,
    random_state=3
)

# Perform Cross-Validation
from sklearn.model_selection import cross_val_score

kf = KFold(n_splits=5, shuffle=True, random_state=3)
cv_scores = cross_val_score(optimized_rf, df2[x], df2[y], cv=kf, scoring='r2')

# Print new cross-validation results
print(f"Optimized Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Optimized Cross-Validation R² Scores: [0.81314546 0.75837451 0.84795975 0.68761423 0.78075032]
# Mean R² Score: 0.7776
# Standard Deviation: 0.0542

# %%
# Define and Train the Random Forest Model
optimized_rf = RandomForestRegressor(
    max_depth=10,
    min_samples_leaf=1,
    min_samples_split=5,
    n_estimators=100,
    random_state=3
)
x = ['Tonsures','Hundi','Tirupati','temperature','Timestamp','weekday','festival_impact']
y = 'Piligrims'
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.27, random_state=3)

# Train the model
optimized_rf.fit(X_train, y_train)

# Now, you can check feature importance
importances = optimized_rf.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': x, 'Importance': importances}).sort_values(by='Importance', ascending=False)

# Print feature importance
print(feature_importance_df)
# Out:
#            Feature  Importance
# 0         Tonsures    0.378767
# 4        Timestamp    0.250835
# 5          weekday    0.173991
# 6  festival_impact    0.126063
# 1            Hundi    0.032415
# 3      temperature    0.023135
# 2         Tirupati    0.014795

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# Initialize a basic model to get feature importance
rf_temp = RandomForestRegressor(n_estimators=100, random_state=3)
rf_temp.fit(X_train, y_train)

# Get feature importance
importances = rf_temp.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': x, 'Importance': importances}).sort_values(by='Importance', ascending=False)
print("Feature Importances:\n", feature_importance_df)

# Remove features with very low importance (threshold: < 0.01)
selected_features = feature_importance_df[feature_importance_df["Importance"] > 0.01]["Feature"].tolist()
print("Selected Features:", selected_features)

# Update X_train and X_test with only important features
X_train = X_train[selected_features]
X_test = X_test[selected_features]
# Out:
# Feature Importances:
#                Feature  Importance
# 4           Timestamp    0.367852
# 7  Piligrims_7Day_Avg    0.283047
# 5             weekday    0.158128
# 6     festival_impact    0.104883
# 3         temperature    0.027526
# 1            Tirumala    0.023272
# 0            Tirupati    0.021631
# 2           condition    0.013661
# Selected Features: ['Timestamp', 'Piligrims_7Day_Avg', 'weekday', 'festival_impact', 'temperature', 'Tirumala', 'Tirupati', 'condition']

# %%
# Define hyperparameter search space
param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],  # More trees
    'max_depth': [5, 10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]
}

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    RandomForestRegressor(random_state=3),
    param_distributions=param_dist,
    n_iter=20,  # Number of random samples to try
    cv=5,  # 5-fold cross-validation
    scoring='r2',
    n_jobs=-1,
    random_state=3
)

# Fit search to data
random_search.fit(X_train, y_train)

# Print best parameters
best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': 10}

# %%
# Train model with best parameters
optimized_rf = RandomForestRegressor(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    random_state=3
)

optimized_rf.fit(X_train, y_train)

# Make predictions
y_pred = optimized_rf.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print results
print(f"Final Model R² Score: {r2:.4f}")
print(f"MAE: {mae:.2f}, MSE: {mse:.2f}, RMSE: {rmse:.2f}")
# Out:
# Final Model R² Score: 0.8030
# MAE: 3869.74, MSE: 26131034.25, RMSE: 5111.85

# %%
##Xgboost

# %%
# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Train XGBoost model
xgb_model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=6, random_state=3)
xgb_model.fit(X_train, y_train)

# Make predictions
y_pred_xgb = xgb_model.predict(X_test)

# Evaluate performance
r2_xgb = r2_score(y_test, y_pred_xgb)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)

print(f"XGBoost R² Score: {r2_xgb:.4f}")
print(f"MAE: {mae_xgb:.2f}, MSE: {mse_xgb:.2f}, RMSE: {rmse_xgb:.2f}")
# Out:
# XGBoost R² Score: 0.7837
# MAE: 4055.17, MSE: 28692438.02, RMSE: 5356.53

# %%
# Define hyperparameter search space
param_dist = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [3, 6, 10, 15],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.2, 0.3]
}

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    XGBRegressor(random_state=3),
    param_distributions=param_dist,
    n_iter=20,  # Number of random samples to try
    cv=5,  # 5-fold cross-validation
    scoring='r2',
    n_jobs=-1,
    random_state=3
)

# Fit search to data
random_search.fit(X_train, y_train)

# Print best parameters
best_params_xgb = random_search.best_params_
print("Best XGBoost Hyperparameters:", best_params_xgb)
# Out:
# Best XGBoost Hyperparameters: {'subsample': 0.6, 'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.8}

# %%
# Train XGBoost with best parameters
optimized_xgb = XGBRegressor(
    n_estimators=best_params_xgb['n_estimators'],
    max_depth=best_params_xgb['max_depth'],
    learning_rate=best_params_xgb['learning_rate'],
    subsample=best_params_xgb['subsample'],
    colsample_bytree=best_params_xgb['colsample_bytree'],
    gamma=best_params_xgb['gamma'],
    random_state=3
)

optimized_xgb.fit(X_train, y_train)

# Make predictions
y_pred_xgb_opt = optimized_xgb.predict(X_test)

# Evaluate performance
r2_xgb_opt = r2_score(y_test, y_pred_xgb_opt)
mae_xgb_opt = mean_absolute_error(y_test, y_pred_xgb_opt)
mse_xgb_opt = mean_squared_error(y_test, y_pred_xgb_opt)
rmse_xgb_opt = np.sqrt(mse_xgb_opt)

print(f"Optimized XGBoost R² Score: {r2_xgb_opt:.2f}")
print(f"MAE: {mae_xgb_opt:.2f}, MSE: {mse_xgb_opt:.2f}, RMSE: {rmse_xgb_opt:.2f}")
# Out:
# Optimized XGBoost R² Score: 0.80
# MAE: 3989.84, MSE: 26608620.14, RMSE: 5158.35

# %%
#combining both

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Random Forest Model
rf_model = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=3)

# XGBoost Model
xgb_model = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)

# %%
# Define Stacking Regressor
stacking_model = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model)],  # Base Models
    final_estimator=LinearRegression(),  # Meta Model
    n_jobs=-1
)

# Train the stacking model
stacking_model.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf',
#                                RandomForestRegressor(max_depth=10,
#                                                      n_estimators=200,
#                                                      random_state=3)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weight...
# ...

# %%
# Make Predictions
y_pred_stack = stacking_model.predict(X_test)

# Evaluate Performance
r2_stack = r2_score(y_test, y_pred_stack)
mae_stack = mean_absolute_error(y_test, y_pred_stack)
mse_stack = mean_squared_error(y_test, y_pred_stack)
rmse_stack = np.sqrt(mse_stack)

print(f"Stacking Model R² Score: {r2_stack:.4f}")
print(f"MAE: {mae_stack:.2f}, MSE: {mse_stack:.2f}, RMSE: {rmse_stack:.2f}")
# Out:
# Stacking Model R² Score: 0.8016
# MAE: 3891.63, MSE: 26320455.79, RMSE: 5130.35

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Random Forest Model
rf_model = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=3)

# XGBoost Model
xgb_model = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)

# %%
# Stacking Regressor with Ridge as the meta-model
stacking_ridge = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model)],  
    final_estimator=Ridge(alpha=1.0),  # Ridge as the meta-model
    n_jobs=-1
)

# Train the stacking model
stacking_ridge.fit(X_train, y_train)

# Make Predictions
y_pred_ridge = stacking_ridge.predict(X_test)

# Evaluate Performance
r2_ridge = r2_score(y_test, y_pred_ridge)
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)
mse_ridge = mean_squared_error(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mse_ridge)

print(f"Stacking with Ridge R² Score: {r2_ridge:.4f}")
print(f"MAE: {mae_ridge:.2f}, MSE: {mse_ridge:.2f}, RMSE: {rmse_ridge:.2f}")
# Out:
# Stacking with Ridge R² Score: 0.8016
# MAE: 3891.63, MSE: 26320455.79, RMSE: 5130.35

# %%
# Stacking Regressor with SVR as the meta-model
stacking_svr = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model)],  
    final_estimator=SVR(kernel='rbf', C=1.0, epsilon=0.1),  # SVR as the meta-model
    n_jobs=-1
)

# Train the stacking model
stacking_svr.fit(X_train, y_train)

# Make Predictions
y_pred_svr = stacking_svr.predict(X_test)

# Evaluate Performance
r2_svr = r2_score(y_test, y_pred_svr)
mae_svr = mean_absolute_error(y_test, y_pred_svr)
mse_svr = mean_squared_error(y_test, y_pred_svr)
rmse_svr = np.sqrt(mse_svr)

print(f"Stacking with SVR R² Score: {r2_svr:.4f}")
print(f"MAE: {mae_svr:.2f}, MSE: {mse_svr:.2f}, RMSE: {rmse_svr:.2f}")
# Out:
# Stacking with SVR R² Score: 0.0076
# MAE: 8077.83, MSE: 131633501.30, RMSE: 11473.16

# %%
#xg boost

# %%
# !pip install lightgbm xgboost scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Random Forest Model
rf_model = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=3)

# XGBoost Model
xgb_model = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)

# LightGBM Model
lgb_model = lgb.LGBMRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)

# %%
# Stacking Regressor with LightGBM and Ridge as the meta-model
stacking_lgb_ridge = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model), ('lgb', lgb_model)],  
    final_estimator=Ridge(alpha=1.0),  # Ridge as the meta-model
    n_jobs=-1
)

# Train the stacking model
stacking_lgb_ridge.fit(X_train, y_train)

# Make Predictions
y_pred_lgb_ridge = stacking_lgb_ridge.predict(X_test)

# Evaluate Performance
r2_lgb_ridge = r2_score(y_test, y_pred_lgb_ridge)
mae_lgb_ridge = mean_absolute_error(y_test, y_pred_lgb_ridge)
mse_lgb_ridge = mean_squared_error(y_test, y_pred_lgb_ridge)
rmse_lgb_ridge = np.sqrt(mse_lgb_ridge)

print(f"Stacking (RF + XGBoost + LightGBM) with Ridge R² Score: {r2_lgb_ridge:.4f}")
print(f"MAE: {mae_lgb_ridge:.2f}, MSE: {mse_lgb_ridge:.2f}, RMSE: {rmse_lgb_ridge:.2f}")
# Out:
# Stacking (RF + XGBoost + LightGBM) with Ridge R² Score: 0.7992
# MAE: 3915.04, MSE: 26633123.69, RMSE: 5160.73

# %%
# Stacking Regressor with LightGBM and SVR as the meta-model
stacking_lgb_svr = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model), ('lgb', lgb_model)],  
    final_estimator=SVR(kernel='rbf', C=1.0, epsilon=0.1),  # SVR as the meta-model
    n_jobs=-1
)

# Train the stacking model
stacking_lgb_svr.fit(X_train, y_train)

# Make Predictions
y_pred_lgb_svr = stacking_lgb_svr.predict(X_test)

# Evaluate Performance
r2_lgb_svr = r2_score(y_test, y_pred_lgb_svr)
mae_lgb_svr = mean_absolute_error(y_test, y_pred_lgb_svr)
mse_lgb_svr = mean_squared_error(y_test, y_pred_lgb_svr)
rmse_lgb_svr = np.sqrt(mse_lgb_svr)

print(f"Stacking (RF + XGBoost + LightGBM) with SVR R² Score: {r2_lgb_svr:.4f}")
print(f"MAE: {mae_lgb_svr:.2f}, MSE: {mse_lgb_svr:.2f}, RMSE: {rmse_lgb_svr:.2f}")
# Out:
# Stacking (RF + XGBoost + LightGBM) with SVR R² Score: 0.0085
# MAE: 8073.13, MSE: 131519837.57, RMSE: 11468.21

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Define hyperparameter grid for LightGBM
param_grid = {
    'n_estimators': [100, 200, 500],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [4, 6, 10],
    'num_leaves': [20, 31, 50],
    'min_child_samples': [10, 20, 30]
}

# Initialize LightGBM model
lgb_model = lgb.LGBMRegressor(random_state=3)

# Perform GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(lgb_model, param_grid, cv=5, scoring='r2', n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)

# Print best parameters
print("Best Parameters for LightGBM:", grid_search.best_params_)

# Use the best model
best_lgb = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 998
# [LightGBM] [Info] Number of data points in the train set: 876, number of used features: 8
# [LightGBM] [Info] Start training from score 68124.123288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_lgb, X_train, y_train, cv=5, scoring='r2')

print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 815
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 8
# [LightGBM] [Info] Start training from score 68135.792857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Define Base Models
rf_model = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=3)
xgb_model = XGBRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)

# Stacking with Ridge Regression as Meta-Model
stacking_model = StackingRegressor(
    estimators=[('rf', rf_model), ('xgb', xgb_model), ('lgb', best_lgb)],  
    final_estimator=Ridge(alpha=1.0),  # Ridge as the meta-model
    n_jobs=-1
)

# Train the stacking model
stacking_model.fit(X_train, y_train)

# Make Predictions
y_pred_stack = stacking_model.predict(X_test)

# Evaluate Performance
r2_stack = r2_score(y_test, y_pred_stack)
mae_stack = mean_absolute_error(y_test, y_pred_stack)
mse_stack = mean_squared_error(y_test, y_pred_stack)
rmse_stack = np.sqrt(mse_stack)

print(f"Stacking (RF + XGBoost + Tuned LightGBM) R² Score: {r2_stack:.4f}")
print(f"MAE: {mae_stack:.2f}, MSE: {mse_stack:.2f}, RMSE: {rmse_stack:.2f}")
# Out:
# Stacking (RF + XGBoost + Tuned LightGBM) R² Score: 0.8048
# MAE: 3861.75, MSE: 25890925.48, RMSE: 5088.31

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
x=['Tonsures',	'Hundi'	,'Tirupati'	,'Tirumala'	,'VIP darshan'	,'tirumala darshan'	,'srinivasam complex'	,'tirumala darshan tickets'	,'tirupati balaji.ap.gov.in',	'condition'	,'temperature'	,'Timestamp'	,'weekday'	,'festival_count'	,'festival_impact']
y='Piligrims'

# %%
x = ['Tonsures', 'Hundi', 'Tirupati','Tirumala','condition', 'temperature', 'Timestamp', 'weekday', 'festival_impact']

# %%
# Define features and target
x = ['Tirupati','Tirumala','condition', 'temperature', 'Timestamp', 'weekday', 'festival_impact']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.2, random_state=3)

# %%
# Define hyperparameter grid for XGBoost
param_grid = {
    'n_estimators': [100, 200, 500],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [4, 6, 10],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Initialize XGBoost model
xgb_model = XGBRegressor(random_state=3)

# Perform GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(xgb_model, param_grid, cv=5, scoring='r2', n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)

# Print best parameters
print("Best Parameters for XGBoost:", grid_search.best_params_)

# Use the best model
best_xgb = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters for XGBoost: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 500, 'subsample': 0.8}

# %%
import matplotlib.pyplot as plt

importance = best_xgb.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': x, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 5))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Feature Importance (XGBoost)")
plt.show()

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_xgb, X_train, y_train, cv=5, scoring='r2')

print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation R² Scores: [0.72368205 0.68971765 0.82961011 0.7061677  0.72918242]
# Mean R² Score: 0.7357
# Standard Deviation: 0.0490

# %%
# Make Predictions
y_pred_xgb = best_xgb.predict(X_test)

# Evaluate Performance
r2_xgb = r2_score(y_test, y_pred_xgb)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)

print(f"Tuned XGBoost R² Score: {r2_xgb:.4f}")
print(f"MAE: {mae_xgb:.2f}, MSE: {mse_xgb:.2f}, RMSE: {rmse_xgb:.2f}")
# Out:
# Tuned XGBoost R² Score: 0.7775
# MAE: 4104.92, MSE: 29514862.70, RMSE: 5432.76

# %%
import optuna
from xgboost import XGBRegressor

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }
    model = XGBRegressor(**params, random_state=3)
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='r2').mean()
    return score

# Run optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)

print("Best parameters:", study.best_trial.params)
# Out:
# [I 2025-03-31 23:29:38,025] A new study created in memory with name: no-name-683fb5be-24b5-4367-8c2b-4f1222076ef0
# [I 2025-03-31 23:29:40,183] Trial 0 finished with value: 0.7348321437835693 and parameters: {'n_estimators': 486, 'learning_rate': 0.023081675824312163, 'max_depth': 4, 'subsample': 0.766805780059499, 'colsample_bytree': 0.8230888286692216}. Best is trial 0 with value: 0.7348321437835693.
# [I 2025-03-31 23:29:41,485] Trial 1 finished with value: 0.7145283460617066 and parameters: {'n_estimators': 463, 'learning_rate': 0.06946836828982715, 'max_depth': 4, 'subsample': 0.7528572261848113, 'colsample_bytree': 0.6481060972051536}. Best is trial 0 with value: 0.7348321437835693.
# [I 2025-03-31 23:29:45,159] Trial 2 finished with value: 0.7056414246559143 and parameters: {'n_estimators': 305, 'learning_rate': 0.0816446922846595, 'max_depth': 9, 'subsample': 0.9347587646753356, 'colsample_bytree': 0.8637951343030669}. Best is trial 0 with value: 0.7348321437835693.
# ...

# %%
from sklearn.ensemble import StackingRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge

xgb_model = XGBRegressor(**study.best_trial.params, random_state=3)
# Use best Optuna params
lgb_model = LGBMRegressor(n_estimators=200, learning_rate=0.1, max_depth=6, random_state=3)
rf_model = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=3)

stacking_model = StackingRegressor(
    estimators=[('xgb', xgb_model), ('lgb', lgb_model), ('rf', rf_model)],
    final_estimator=Ridge(alpha=1.0),
    n_jobs=-1
)

stacking_model.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8230888286692216,
#                                             device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None,
#                                             feature_weights=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
# ...

# %%
# Make predictions on the test set
y_pred_stack = stacking_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Evaluate the Stacking Model
r2_stack = r2_score(y_test, y_pred_stack)
mae_stack = mean_absolute_error(y_test, y_pred_stack)
mse_stack = mean_squared_error(y_test, y_pred_stack)
rmse_stack = np.sqrt(mse_stack)

# Print results
print(f"Stacking Regressor R² Score: {r2_stack:.4f}")
print(f"Mean Absolute Error (MAE): {mae_stack:.2f}")
print(f"Mean Squared Error (MSE): {mse_stack:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse_stack:.2f}")
# Out:
# Stacking Regressor R² Score: 0.7861
# Mean Absolute Error (MAE): 4017.80
# Mean Squared Error (MSE): 28376632.93
# Root Mean Squared Error (RMSE): 5326.97

# %%
import matplotlib.pyplot as plt

importance = best_xgb.feature_importances_ # Feature importance from XGBoost
feature_importance_df = pd.DataFrame({'Feature': x, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importance
plt.figure(figsize=(10, 5))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Feature Importance (XGBoost)")
plt.show()

# %%
# Define features and target
x =['Tirupati'	,'Tirumala'	, 'condition'	,'temperature'	,'Timestamp','weekday','festival_impact','Piligrims_7Day_Avg']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import numpy as np

# Normalize input features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define Neural Network
from tensorflow.keras.layers import LeakyReLU

model = Sequential([
    Dense(256, input_shape=(X_train.shape[1],)),
    LeakyReLU(alpha=0.1),
    Dropout(0.4),
    Dense(128),
    LeakyReLU(alpha=0.1),
    Dropout(0.3),
    Dense(64),
    LeakyReLU(alpha=0.1),
    Dense(1)
])


# Compile Model
from tensorflow.keras.optimizers import Nadam
model.compile(optimizer=Nadam(learning_rate=0.005), loss='mse', metrics=['mae'])


# Learning Rate Scheduler to reduce overfitting
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

# Train Model
history = model.fit(X_train_scaled, y_train, epochs=200, batch_size=16, 
                    validation_data=(X_test_scaled, y_test), callbacks=[lr_scheduler])
# Out:
# C:\Users\girishmunigeti\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\girishmunigeti\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 4596673536.0000 - mae: 66653.7812 - val_loss: 961937600.0000 - val_mae: 29251.5938 - learning_rate: 0.0050
# Epoch 2/200
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 450526944.0000 - mae: 17084.5684 - val_loss: 100827632.0000 - val_mae: 7843.6177 - learning_rate: 0.0050
# Epoch 3/200
# ...

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Make Predictions
y_pred_nn = model.predict(X_test_scaled)

# Evaluate Performance
r2_nn = r2_score(y_test, y_pred_nn)
mae_nn = mean_absolute_error(y_test, y_pred_nn)
mse_nn = mean_squared_error(y_test, y_pred_nn)
rmse_nn = np.sqrt(mse_nn)

print(f"Neural Network R² Score: {r2_nn:.4f}")
print(f"Mean Absolute Error (MAE): {mae_nn:.2f}")
print(f"Mean Squared Error (MSE): {mse_nn:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse_nn:.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Neural Network R² Score: 0.7989
# Mean Absolute Error (MAE): 4127.45
# Mean Squared Error (MSE): 26676757.25
# Root Mean Squared Error (RMSE): 5164.95

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define features and target
x = ['Tirupati','Tirumala', 'temperature', 'Timestamp', 'weekday', 'festival_impact']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Define hyperparameter grid for LightGBM
param_grid = {
    'n_estimators': [100, 200, 500],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [4, 6, 10],
    'num_leaves': [20, 31, 50],
    'min_child_samples': [10, 20, 30]
}

# Initialize LightGBM model
lgb_model = lgb.LGBMRegressor(random_state=3)

# Perform GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(lgb_model, param_grid, cv=5, scoring='r2', n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)

# Print best parameters
print("Best Parameters for LightGBM:", grid_search.best_params_)

# Use the best model
best_lgb = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# C:\Users\girishmunigeti\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 732
# [LightGBM] [Info] Number of data points in the train set: 876, number of used features: 6
# [LightGBM] [Info] Start training from score 68124.123288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_lgb, X_train, y_train, cv=5, scoring='r2')

print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000454 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 570
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 6
# [LightGBM] [Info] Start training from score 68135.792857
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Make Predictions
y_pred_lgb = best_lgb.predict(X_test)

# Evaluate Performance
r2_lgb = r2_score(y_test, y_pred_lgb)
mae_lgb = mean_absolute_error(y_test, y_pred_lgb)
mse_lgb = mean_squared_error(y_test, y_pred_lgb)
rmse_lgb = np.sqrt(mse_lgb)

print(f"Tuned LightGBM R² Score: {r2_lgb:.4f}")
print(f"MAE: {mae_lgb:.2f}, MSE: {mse_lgb:.2f}, RMSE: {rmse_lgb:.2f}")
# Out:
# Tuned LightGBM R² Score: 0.7847
# MAE: 4086.63, MSE: 28552838.78, RMSE: 5343.49

# %%
pip install lightgbm xgboost scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Define features and target
x = ['Tirupati','Tirumala','temperature', 'Timestamp', 'weekday', 'festival_impact']
y = 'Piligrims'

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df2[x], df2[y], test_size=0.20, random_state=3)

# %%
# Define hyperparameter grid for Random Forest
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize Random Forest model
rf_model = RandomForestRegressor(random_state=3)

# Perform GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(rf_model, param_grid, cv=5, scoring='r2', n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)

# Print best parameters
print("Best Parameters for Random Forest:", grid_search.best_params_)

# Use the best model
best_rf = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Parameters for Random Forest: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_rf, X_train, y_train, cv=5, scoring='r2')

print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation R² Scores: [0.72450254 0.70499707 0.82607717 0.72597863 0.73622587]
# Mean R² Score: 0.7436
# Standard Deviation: 0.0425

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_rf, X_train, y_train, cv=5, scoring='r2')

print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean R² Score: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
# Out:
# Cross-Validation R² Scores: [0.76195515 0.80497061 0.76802383 0.75885748 0.82071856]
# Mean R² Score: 0.7829
# Standard Deviation: 0.0251

# %%
from sklearn.ensemble import RandomForestRegressor

# Define hyperparameter grid for Random Forest
rf_param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [4, 6, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize Random Forest model
rf_model = RandomForestRegressor(random_state=3)

# Perform GridSearchCV with 5-fold cross-validation
rf_grid_search = GridSearchCV(rf_model, rf_param_grid, cv=7, scoring='r2', n_jobs=-1, verbose=1)
rf_grid_search.fit(X_train, y_train)

# Print best parameters
print("Best Parameters for Random Forest:", rf_grid_search.best_params_)

# Use the best model
best_rf = rf_grid_search.best_estimator_

# Perform 5-fold cross-validation
rf_cv_scores = cross_val_score(best_rf, X_train, y_train, cv=7, scoring='r2')

print(f"Cross-Validation R² Scores: {rf_cv_scores}")
print(f"Mean R² Score: {rf_cv_scores.mean():.4f}")
print(f"Standard Deviation: {rf_cv_scores.std():.4f}")

# Make Predictions
y_pred_rf = best_rf.predict(X_test)

# Evaluate Performance
r2_rf = r2_score(y_test, y_pred_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)

print(f"Tuned Random Forest R² Score: {r2_rf:.4f}")
print(f"MAE: {mae_rf:.2f}, MSE: {mse_rf:.2f}, RMSE: {rmse_rf:.2f}")
# Out:
# Fitting 7 folds for each of 108 candidates, totalling 756 fits
# Best Parameters for Random Forest: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Cross-Validation R² Scores: [0.71386762 0.69093124 0.80067546 0.83108818 0.65957943 0.80434526
#  0.70881428]
# Mean R² Score: 0.7442
# Standard Deviation: 0.0616
# Tuned Random Forest R² Score: 0.7815
# MAE: 4055.20, MSE: 28981744.93, RMSE: 5383.47

# %%
print(df2.isnull().sum())
# Out:
# Piligrims           0
# Tonsures            0
# Hundi               0
# Tirupati            0
# Tirumala            0
# VIP darshan         0
# tirumala darshan    0
# condition           0
# temperature         0
# Timestamp           0
# weekday             0
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(df2[['Tonsures','Hundi','weekday','temperature','Tirupati','condition',
       'Tirumala','VIP darshan','Timestamp']],df2['Piligrims'],test_size=0.27,random_state=3)

# %%
#Model Training
model2=LinearRegression()

# %%
model2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_train.isnull().sum())  # Shows number of missing values per column
print(y_train.isnull().sum())  # Check target variable as well
# Out:
# Tonsures       0
# Hundi          0
# weekday        0
# temperature    0
# Tirupati       0
# condition      0
# Tirumala       0
# VIP darshan    0
# Timestamp      0
# dtype: int64
# 0

# %%
X_train = x_train.dropna()
y_train = y_train.loc[x_train.index]  # Ensure target variable aligns

# %%
print(x_train.isnull().sum())  # Shows number of missing values per column
print(y_train.isnull().sum())  # Check target variable as well
# Out:
# Tonsures       0
# Hundi          0
# weekday        0
# temperature    0
# Tirupati       0
# condition      0
# Tirumala       0
# VIP darshan    0
# Timestamp      0
# dtype: int64
# 0

# %%
print(df2.isnull().sum())
# Out:
# Piligrims           0
# Tonsures            0
# Hundi               0
# Tirupati            0
# Tirumala            0
# VIP darshan         0
# tirumala darshan    0
# condition           0
# temperature         0
# Timestamp           0
# weekday             0
# dtype: int64

# %%
# !pip install xgboost

import xgboost as xgb
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
x_train,x_test,y_train,y_test=train_test_split(df2[['Tonsures','Hundi','weekday','temperature','Tirupati','condition',
       'Tirumala','VIP darshan','Timestamp']],df2['Piligrims'],test_size=0.27,random_state=3)

# %%
dtrain=xgb.DMatrix(x_train,label=y_train)
dtest=xgb.DMatrix(x_test,label=y_test)
print(dtrain)

# %%
param={
    'objective':'reg:squarederror',
    'max_depth':5,
    'eta':0.4,
    'subsample':0.8,
    'colsample_bytree':0.8
}
num_round=10
model4=xgb.train(param,dtrain,num_round)
y_pred=model4.predict(dtest)

# %%
#Model Evalution
mse=mean_squared_error(y_test,y_pred)
print(mse)
r2 = r2_score(y_test, y_pred)
print(r2)
print(mean_absolute_error(y_test,y_pred))
# Out:
# 35692267.99693748
# 0.7481698393821716
# 4473.093519056166

# %%
df2 = df2.rename(columns={'Piligrims_7Day_Avg': 'holidays_new'})

# %%
#extra trees regressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assuming df2 is already loaded
# Define features and target
features = ['Timestamp', 'weekday', 'festival_impact','holidays_new' ]
target = 'Piligrims'

# Train-test split
X = df2[features]
y = df2[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3)

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Hyperparameter Tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

etr = ExtraTreesRegressor(random_state=3)
grid_search = GridSearchCV(etr, param_grid, cv=5, scoring='r2', n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)

# Best model from Grid Search
best_etr = grid_search.best_estimator_

# Cross-Validation Score (5-Fold CV)
cv = KFold(n_splits=5, shuffle=True, random_state=3)
cv_scores = cross_val_score(best_etr, X_train_scaled, y_train, cv=cv, scoring='r2')
print(f"Cross-Validation R² Scores: {cv_scores}")
print(f"Mean CV R² Score: {np.mean(cv_scores):.4f}")

# Predictions
y_pred = best_etr.predict(X_test_scaled)

# Evaluation Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print evaluation results
print("\nModel Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R² Score: {r2:.2f}")

# Feature Importance Plot
importances = best_etr.feature_importances_
plt.figure(figsize=(8, 5))
plt.barh(features, importances, color='purple')
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Feature Importance in Extra Trees Regressor")
plt.show()
# Out:
# Cross-Validation R² Scores: [0.78420693 0.78673915 0.78093092 0.77311338 0.81999451]
# Mean CV R² Score: 0.7890
#
# Model Evaluation Metrics:
# Mean Absolute Error (MAE): 3754.22
# Mean Squared Error (MSE): 23842194.03
# Root Mean Squared Error (RMSE): 4882.85
# R² Score: 0.82

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime

# Define the date for prediction
future_date = "2025-01-01"

# Convert date to UNIX timestamp
timestamp = int(time.mktime(datetime.strptime(future_date, "%Y-%m-%d").timetuple()))

# Determine the weekday (0 = Monday, 6 = Sunday)
weekday = datetime.strptime(future_date, "%Y-%m-%d").weekday()

# Compute Piligrims_7Day_Avg from past 7 days (Dec 25-31, 2024)
past_7_days = df2[(df2["Timestamp"] >= timestamp - (7 * 86400)) & (df2["Timestamp"] < timestamp)]
Piligrims_7Day_Avg = past_7_days["Piligrims"].mean()

# Handle missing data (if no past records exist)
if np.isnan(Piligrims_7Day_Avg):
    Piligrims_7Day_Avg = df2["Piligrims"].mean()  # Use overall mean

# Create the new data point for prediction
new_data = {
    'Timestamp': timestamp,
    'weekday': weekday,
    'festival_impact': 60000,  # Adjusted based on festival impact
    'holidays_new': Piligrims_7Day_Avg  # Renamed correctly
}

# Convert to DataFrame
new_data_df = pd.DataFrame([new_data])

# Scale using the trained scaler
X_new_scaled = scaler.transform(new_data_df)

# Predict the number of pilgrims
predicted_pilgrims = best_etr.predict(X_new_scaled)

# Output the prediction
print(f"Predicted Number of Pilgrims on {future_date}: {predicted_pilgrims[0]:,.0f}")
# Out:
# Predicted Number of Pilgrims on 2025-01-01: 78,142

# %%
print(weekday)
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime

# Define the date for prediction
future_date = "2025-04-05"

# Convert date to UNIX timestamp
timestamp = int(time.mktime(datetime.strptime(future_date, "%Y-%m-%d").timetuple()))

# Determine if the date is a weekend (Saturday=5, Sunday=6 → Set to 1, Else 0)
weekday_num = datetime.strptime(future_date, "%Y-%m-%d").weekday()
weekday = 1 if weekday_num in [5, 6] else 0  # 1 for Saturday/Sunday, 0 for weekdays

# Compute Piligrims_7Day_Avg from past 7 days (Dec 29, 2024 - Jan 4, 2025)
past_7_days = df2[(df2["Timestamp"] >= timestamp - (7 * 86400)) & (df2["Timestamp"] < timestamp)]
Piligrims_7Day_Avg = past_7_days["Piligrims"].mean()

# Handle missing values (if no past records exist)
if np.isnan(Piligrims_7Day_Avg):
    Piligrims_7Day_Avg = df2["Piligrims"].mean()  # Use dataset mean as fallback

# Create the new data point for prediction (features must match training data)
new_data = {
    'Timestamp': timestamp,
    'weekday': weekday,  # Weekend indicator
    'festival_impact': 60000,  # Hypothetical festival impact
    'holidays_new': Piligrims_7Day_Avg  # Corrected feature name
}

# Convert to DataFrame
new_data_df = pd.DataFrame([new_data])

# Scale using the trained scaler
X_new_scaled = scaler.transform(new_data_df)

# Predict the number of pilgrims
predicted_pilgrims = best_etr.predict(X_new_scaled)

# Output the prediction
print(f"Predicted Number of Pilgrims on {future_date}: {predicted_pilgrims[0]:,.0f}")
# Out:
# Predicted Number of Pilgrims on 2025-04-05: 71,008

# %%
print(weekday)
# Out:
# 1

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("realtime.csv")  # Ensure the file path is correct

# Count total rows
total_days = len(df)

# Count holiday and non-holiday days
holiday_days = df[df["holidays"] == 1]
non_holiday_days = df[df["holidays"] == 0]

# Calculate the percentage of holiday days
holiday_percentage = (len(holiday_days) / total_days) * 100

# Calculate average pilgrims for holidays and non-holidays
avg_pilgrims_holiday = holiday_days["Piligrims"].mean()
avg_pilgrims_non_holiday = non_holiday_days["Piligrims"].mean()

# Calculate the percentage increase in pilgrims on holidays
percentage_increase = ((avg_pilgrims_holiday - avg_pilgrims_non_holiday) / avg_pilgrims_non_holiday) * 100

# Print results
print(f"Percentage of days that are holidays: {holiday_percentage:.2f}%")
print(f"Average pilgrims on holidays: {avg_pilgrims_holiday:.2f}")
print(f"Average pilgrims on non-holidays: {avg_pilgrims_non_holiday:.2f}")
print(f"Percentage increase in pilgrims on holidays: {percentage_increase:.2f}%")
# Out:
# Percentage of days that are holidays: 84.22%
# Average pilgrims on holidays: 68508.99
# Average pilgrims on non-holidays: 66281.01
# Percentage increase in pilgrims on holidays: 3.36%
